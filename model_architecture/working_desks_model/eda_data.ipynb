# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('preprocessed_working_desks_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8775 entries, 0 to 8774
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   row           8775 non-null   int64
#  1   desk          8775 non-null   object
#  2   date          8775 non-null   object
#  3   firstHalf     8775 non-null   int64
#  4   secondHalf    8775 non-null   int64
#  5   day_of_week   8775 non-null   int64
#  6   day_of_month  8775 non-null   int64
#  7   month         8775 non-null   int64
#  8   week_of_year  8775 non-null   int64
# dtypes: int64(7), object(2)
# memory usage: 617.1+ KB

# %%
df.describe().transpose()
# Out:
#                count         mean          std  min     25%     50%     75%  \
# row           8775.0  4388.000000  2533.268640  1.0  2194.5  4388.0  6581.5
# firstHalf     8775.0     0.503134     0.500019  0.0     0.0     1.0     1.0
# secondHalf    8775.0     0.498006     0.500025  0.0     0.0     0.0     1.0
# day_of_week   8775.0     2.000000     1.414294  0.0     1.0     2.0     3.0
# day_of_month  8775.0    15.600000     8.770729  1.0     8.0    15.0    23.0
# month         8775.0     1.969231     0.822225  1.0     1.0     2.0     3.0
# week_of_year  8775.0     7.000000     3.741871  1.0     4.0     7.0    10.0
#
#                  max
# row           8775.0
# firstHalf        1.0
# secondHalf       1.0
# day_of_week      4.0
# day_of_month    31.0
# month            3.0
# week_of_year    13.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x='firstHalf', data=df)
# Out:
# <Axes: xlabel='firstHalf', ylabel='count'>

# %%
sns.countplot(x='secondHalf', data=df)
# Out:
# <Axes: xlabel='secondHalf', ylabel='count'>

# %%
sns.heatmap(df.corr())
# Out:
# /var/folders/y3/7t134x0x04xglfbbg5tf61nh0000gn/T/ipykernel_27208/1072140413.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
df.corr()['firstHalf'].sort_values()
# Out:
# /var/folders/y3/7t134x0x04xglfbbg5tf61nh0000gn/T/ipykernel_27208/2760598295.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['firstHalf'].sort_values()
# week_of_year   -0.008955
# day_of_month   -0.007875
# row            -0.007517
# month          -0.005310
# secondHalf      0.005609
# day_of_week     0.020468
# firstHalf       1.000000
# Name: firstHalf, dtype: float64

# %%
df.corr()['secondHalf'].sort_values()
# Out:
# /var/folders/y3/7t134x0x04xglfbbg5tf61nh0000gn/T/ipykernel_27208/2088304180.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['secondHalf'].sort_values()
# day_of_month   -0.020089
# week_of_year    0.002741
# row             0.004230
# firstHalf       0.005609
# month           0.011217
# day_of_week     0.020307
# secondHalf      1.000000
# Name: secondHalf, dtype: float64
